# %%
#import cv2 #opencv
#import numpy as np
#from matplotlib import pyplot as plt

#img = cv2.imread('test3.jpg')

#kernel = np.ones((5,5),np.float32)/25
#dst = cv2.filter2D(img,-1,kernel)

#plt.subplot(121),plt.imshow(img),plt.title('Original')
#plt.xticks([]), plt.yticks([])
#plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
#plt.xticks([]), plt.yticks([])
#plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import skimage
from skimage import color
from skimage import io
import skimage.color as skic
import skimage.filters as skif
import skimage.data as skid
import skimage.util as sku

# %matplotlib inline

def show(img):
    fig, ax = plt.subplots(1, 1, figsize=(15, 15))
    ax.imshow(img, cmap=plt.cm.gray)
    ax.set_axis_off()
    plt.show()
    
#img = cv2.imread('test3.jpg')
img = color.rgb2gray(io.imread('test3.jpg'))
show(img)

# %%
show(skif.gaussian(img, 5.))

# %%
sobimg = skif.sobel(img)
show(sobimg)

# %%
from ipywidgets import widgets

@widgets.interact(x=(0.01, .2, .005))
def edge(x):
    show(sobimg < x)
# Out:
# interactive(children=(FloatSlider(value=0.105, description='x', max=0.2, min=0.01, step=0.005), Output()), _do…

# %%
#img = skimage.img_as_float(skid.astronaut())

# We take a portion of the image to show the details.
#img = img[50:200, 150:300]

# We add Gaussian noise.
img_n = sku.random_noise(img)
show(img_n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-ea7b6957535c> in <module>
#       5
#       6 # We add Gaussian noise.
# ----> 7 img_n = sku.random_noise(img)
#       8 show(img_n)
#
# G:\Anaconda\lib\site-packages\skimage\util\noise.py in random_noise(image, mode, seed, clip, **kwargs)
#      88
#      89     # Detect if a signed image was input
# ---> 90     if image.min() < 0:
#      91         low_clip = -1.
#      92     else:
#
# G:\Anaconda\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity
